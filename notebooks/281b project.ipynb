# %%
# %autoreload 2
from project_281b import *

data = load_dataset('digits', standardize=True)

# %%
dataset_name = 'digits'
policy_name = 'random_selection'
num_blocks = -1
rmse_df, err_df = output_results(dataset_name, policy_name, num_blocks)
# Out:
# Index([gaussian: 93.855, kNN (dot): 100.883, kNN (euclidean): 84.633, mean: 118.629, svd: 696.863], dtype=object)
# Index([gaussian, full: 0.221, gaussian, retrained: 0.219, kNN (dot): 0.261, kNN (dot), full: 0.230, kNN (euclidean): 0.175, kNN (euclidean), full: 0.180, mean, full: 0.341, mean, retrained: 0.251, mean, retrained, 5 clusters: 0.259, svd, full: 0.340, mcf quad: 0.361, mcf log: 0.352], dtype=object)

# %%
params = [
    ('digits', 'random', -1),
    ('digits', 'random', 8),
    ('digits', 'clustered', -1),
    ('digits', 'clustered', 8)
]
output_auc_tables(params)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  random &  random, blocks &  clustered &  clustered, blocks \\
# \midrule
# gaussian        &   93.16 &           93.16 &      93.16 &              93.16 \\
# kNN (dot)       &   97.59 &           97.59 &      97.59 &              97.59 \\
# kNN (euclidean) &   87.16 &           87.16 &      87.16 &              87.16 \\
# mean            &  114.02 &          114.02 &     114.02 &             114.02 \\
# svd             &  638.87 &          638.87 &     638.87 &             638.87 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrrr}
# \toprule
# {} &  random &  random, blocks &  clustered &  clustered, blocks \\
# \midrule
# gaussian, full                     &   0.221 &           0.273 &      0.206 &              0.230 \\
# gaussian, retrained                &   0.219 &           0.274 &      0.206 &              0.242 \\
# kNN (dot)                          &   0.261 &           0.294 &      0.241 &              0.267 \\
# ...
